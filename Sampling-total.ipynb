# %%
import pandas as pd
import random

prob = pd.read_csv("whole_id_boot.csv")
#num = pd.read_csv("num.csv")
# Out:
# 9228

# %%
# the whole without 

df_selectedID = []
selectedID =[]
samplingSize=1

while(samplingSize<51):
    selectedID =[]

    for k in range(len(prob)):
        rand = random.randint(0,len(prob)-1)
        selectedID.append(prob['id'].loc[rand])
            

    samplingSize+=1;
    

    df_selectedID.append(selectedID)
    
df_selectedID = pd.DataFrame(df_selectedID)
df_selectedID2=df_selectedID.transpose()
df_selectedID2
# Out:
#           0       1       2       3       4       5       6       7       8   \
# 0     107908   25273     304  113847   60092   17174    6277   96299  105898
# 1      96222   21630  100737    4586   39759   35625   73123   63668  104689
# 2      41028   63738  120860  125978   72484  107902   64267   34152  114409
# 3       8951   92634   17854  122203  126222  113870   96888   95678   22701
# 4      44135   67049   46889  125978   16879   19509   72590   46718   71952
# 5      33958   10053   59363   93924   22539    3873   61120   23483   35205
# 6      11467   96256   59304    1751   34935  125432  122208   87902   72200
# 7      54069   60102   24270   46643   55126  125747   96363   32233   69923
# 8      73915   94166   42130   55787   29402  111393   39834   58834   47024
# 9      60262  101782   72121   73178   60186   39200   24954   29626  108068
# 10     94087   39329  129097   29642   83169   73134   46792   71881   94759
# ...

# %%
# ## the whole without 


# selectedID =[]
# samplingSize=1

# while(samplingSize<len(prob)):


#     rand = random.uniform(0, 1)

#     for k in range(len(prob)):
#         if(prob['cm_prob'].loc[k]>rand):
#             selectedID.append(prob['id'].loc[k])
#             break;

#     samplingSize+=1;
    


# df_selectedID = pd.DataFrame(selectedID)
# df_selectedID
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-2a94cddda239> in <module>
#      11
#      12     for k in range(len(prob)):
# ---> 13         if(prob['cm_prob'].loc[k]>rand):
#      14             selectedID.append(prob['id'].loc[k])
#      15             break;
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1860             key = list(key)
#    1861
# -> 1862         labels = self.obj._get_axis(axis)
# ...

# %%
df_selectedID2.to_csv( 'sampling_whole_50.csv')

# %%
random.randint(0,10)

# %% [markdown]
# # CitiBIKE

# %%
num_citi = pd.read_csv("whole_id_boot_citi.csv")
#count_citi = pd.read_csv("count_citi.csv")

# %%
df_selectedID_citi = []
selectedID =[]
samplingSize=1

while(samplingSize<51):
    selectedID =[]

    for k in range(len(num_citi)):
        rand = random.randint(0,len(num_citi)-1)
        selectedID.append(num_citi['id'].loc[rand])
            

    samplingSize+=1;
    

    df_selectedID_citi.append(selectedID)
    
df_selectedID_citi = pd.DataFrame(df_selectedID_citi)
df_selectedID_citi2=df_selectedID_citi.transpose()
df_selectedID_citi2
# Out:
#             0       1       2       3       4       5       6       7   \
# 0        67213   40209   95105   93579  119660   30332  132291   97952
# 1        10840   21130  130633  106051   64524  104856   58798  133478
# 2        32558   37366   53959   86539   58775  104795   33002    4332
# 3        50433   66623   79974   13393  129202   63797   21965   95462
# 4        72048   68211  102774   67007   81317   29895  106823   24984
# 5       108524  123596  122694   31269    6982     250   67578   36610
# 6       116617   70515  120811  119097  107353   23109  107619   73496
# 7        87944   87032  126956  129836   79152   61092  101903   14197
# 8        22268    8495   58800   73213  132599   55614   55325  126701
# 9       102801   90095   70965   37535   76974  129515   35945   76586
# 10       57805   71756   36485   63709   22983   25185   54380   15229
# 11       61515   94321   95571   78844   23716   11379   23924   97254
# ...

# %%
df_selectedID_citi2.to_csv( 'Citi_sampling_whole_50.csv')

# %%
df_selectedID_citi = pd.DataFrame(df_selectedID_citi)
df_selectedID_citi2=df_selectedID_citi.transpose()

#df_selectedID_citi2

# %%
# new_df = pd.DataFrame(zip(prob[prob['zone']==3]['id'],prob[prob['zone']==3]['cm_prob']),columns=['id','cm_prob'])
# new_df
# #new_df['cm_prob'].loc[2]

# %%
# rand = random.uniform(0, 1)
# a = new_df['cm_prob'].loc[2]
# #rand-a

# %%
    # new_df = pd.DataFrame(zip(prob[prob['zone']==317]['id'],prob[prob['zone']==317]['cm_prob']),columns=['id','cm_prob'])
    # new_df['id'].loc[1]

# %%
# len(num)

# %%
df_selectedID =[]
selected_id = []
selected_id2 = []

selected_id.append(1)
selected_id.append(2)
selected_id.append(3)
selected_id.append(4)
selected_id2.append(2)
selected_id2.append(2)
selected_id2.append(2)
selected_id2.append(2)

# %%
df_selectedID.append(selected_id)
df_selectedID

# %%
df_selectedID.append(selected_id2)

# %%
df_selectedID

# %%
df_selectedID =pd.DataFrame(df_selectedID)
df_selectedID.transpose()

# %%
df_selectedID

# %%
df_selectedID =pd.concat(df_selectedID,selected_id2)

# %%
df_selectedID

# %%
df_selectedID =[0]
sameplingSize=1

while(sameplingSize<2):
    id_list = []
    selected_id =[]
    for i in range(len(num)):
        zoneNum = num['num'].iloc[i]
        new_df = pd.DataFrame(zip(prob[prob['zone']==(i+1)]['id'],prob[prob['zone']==(i+1)]['cm_prob']),columns=['id','cm_prob'])


        if(zoneNum==0):
            continue;


        for j in range(zoneNum):


            rand = random.uniform(0, 1)

            for k in range(len(new_df)):
                if(new_df['cm_prob'].loc[k]>rand):
                    id_list.append((i+1))
                    selected_id.append(new_df['id'].loc[k])
                    break;


        new_df = new_df[0:0]

            ###something in zone 2 is wrong


    df_selectedID =zip(df_selectedID,selected_id)
    sameplingSize+=1;

df = pd.DataFrame(zip(id_list,df_selectedID))

# %%
len(id_list)

# %%
len(selected_id)

# %%
df = pd.DataFrame(zip(id_list,selected_id))

# %%
df

# %%
dr_selectedID.to_csv( 'sampling_id.csv')
